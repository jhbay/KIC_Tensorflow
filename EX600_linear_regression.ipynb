# %%
import tensorflow as tf

x_data = [1, 2, 3, 4]
y_data = [2, 4, 6, 8]

W = tf.Variable(tf.random_uniform([1], -1.0, 1.0), name='W')
b = tf.Variable(tf.random_uniform([1], -1.0, 1.0), name='b')

X = tf.placeholder(tf.float32, name="X")
Y = tf.placeholder(tf.float32, name="Y")

hypothesis = W * X + b

cost = tf.reduce_mean(tf.square(hypothesis - Y))

optimizer = tf.train.GradientDescentOptimizer(learning_rate=0.1)

train_op = optimizer.minimize(cost)


with tf.Session() as sess:
    sess.run(tf.global_variables_initializer())

    for step in range(1,501):
        _, cost_val = sess.run([train_op, cost], feed_dict={X: x_data, Y: y_data})

        print(step, cost_val, sess.run(W), sess.run(b))
    saver.save(sess, './')

    print("\n=== Test ===")
    print("X: 5, Y:", sess.run(hypothesis, feed_dict={X: 5}))
    print("X: 2.5, Y:", sess.run(hypothesis, feed_dict={X: 2.5}))
# Out:
# 1 6.34298 [ 2.18296862] [ 1.24683273]
# 2 2.94633 [ 1.28509927] [ 0.90598184]
# 3 1.41549 [ 1.90445948] [ 1.08223581]
# 4 0.722707 [ 1.50665247] [ 0.91355896]
# 5 0.406518 [ 1.78989434] [ 0.97752094]
# 6 0.259717 [ 1.61629236] [ 0.88706958]
# 7 0.189252 [ 1.74831903] [ 0.90150946]
# 8 0.15333 [ 1.67508578] [ 0.8470481]
# 9 0.13317 [ 1.73893297] [ 0.84009558]
# 10 0.120324 [ 1.7104857] [ 0.80260998]
# 11 0.110986 [ 1.74345219] [ 0.78684515]
# 12 0.103434 [ 1.73485136] [ 0.75775003]
# 13 0.0968817 [ 1.7536993] [ 0.73877436]
# 14 0.0909646 [ 1.7537632] [ 0.71416986]
# 15 0.0855083 [ 1.76603341] [ 0.69445425]
# 16 0.080424 [ 1.7697562] [ 0.67254668]
# 17 0.0756621 [ 1.77884853] [ 0.65315926]
# 18 0.0711912 [ 1.78399611] [ 0.63310313]
# 19 0.0669885 [ 1.79145038] [ 0.61448443]
# 20 0.0630357 [ 1.79703259] [ 0.59586239]
# 21 0.059317 [ 1.80355251] [ 0.57817358]
# 22 0.055818 [ 1.80913699] [ 0.56076264]
# 23 0.0525257 [ 1.81505013] [ 0.54404163]
# 24 0.0494276 [ 1.82045412] [ 0.52770823]
# 25 0.0465122 [ 1.82591891] [ 0.51193953]
# 26 0.0437688 [ 1.83107078] [ 0.49659216]
# 27 0.0411873 [ 1.83616853] [ 0.48173836]
# 28 0.038758 [ 1.84104645] [ 0.46730638]
# 29 0.0364719 [ 1.84582353] [ 0.45332184]
# 30 0.0343208 [ 1.85042727] [ 0.43974569]
# 31 0.0322965 [ 1.85491347] [ 0.4265829]
# 32 0.0303916 [ 1.85925186] [ 0.41380963]
# 33 0.028599 [ 1.86346924] [ 0.40142176]
# 34 0.0269122 [ 1.86755455] [ 0.38940281]
# 35 0.0253249 [ 1.87152135] [ 0.37774497]
# 36 0.0238312 [ 1.87536681] [ 0.36643529]
# 37 0.0224256 [ 1.87909889] [ 0.35546482]
# 38 0.0211029 [ 1.88271809] [ 0.34482238]
# 39 0.0198582 [ 1.88622975] [ 0.33449885]
# 40 0.0186869 [ 1.88963568] [ 0.3244842]
# 41 0.0175847 [ 1.89294004] [ 0.31476951]
# 42 0.0165476 [ 1.89614522] [ 0.30534557]
# 43 0.0155716 [ 1.89925456] [ 0.29620382]
# 44 0.0146531 [ 1.90227091] [ 0.28733581]
# 45 0.0137888 [ 1.90519667] [ 0.27873319]
# 46 0.0129756 [ 1.90803504] [ 0.27038822]
# 47 0.0122102 [ 1.91078842] [ 0.26229307]
# 48 0.0114901 [ 1.9134593] [ 0.25444028]
# 49 0.0108124 [ 1.9160502] [ 0.24682257]
# 50 0.0101746 [ 1.91856372] [ 0.23943298]
# 51 0.00957451 [ 1.92100167] [ 0.23226453]
# 52 0.00900978 [ 1.9233669] [ 0.22531079]
# 53 0.00847835 [ 1.92566121] [ 0.2185652]
# 54 0.0079783 [ 1.92788684] [ 0.21202157]
# 55 0.00750773 [ 1.93004584] [ 0.20567387]
# 56 0.00706492 [ 1.93214023] [ 0.19951621]
# 57 0.0066482 [ 1.9341718] [ 0.19354285]
# 58 0.00625608 [ 1.93614268] [ 0.18774837]
# 59 0.0058871 [ 1.93805444] [ 0.18212736]
# 60 0.00553985 [ 1.9399091] [ 0.17667466]
# 61 0.00521311 [ 1.94170809] [ 0.17138515]
# 62 0.00490563 [ 1.94345331] [ 0.16625406]
# 63 0.00461629 [ 1.94514632] [ 0.16127659]
# 64 0.00434401 [ 1.94678843] [ 0.1564481]
# 65 0.0040878 [ 1.94838178] [ 0.15176427]
# 66 0.00384668 [ 1.94992697] [ 0.14722052]
# 67 0.0036198 [ 1.95142627] [ 0.14281292]
# 68 0.00340631 [ 1.9528805] [ 0.13853724]
# 69 0.00320539 [ 1.95429111] [ 0.13438952]
# 70 0.00301634 [ 1.95565975] [ 0.13036609]
# 71 0.00283843 [ 1.95698714] [ 0.12646303]
# 72 0.00267101 [ 1.95827496] [ 0.12267688]
# 73 0.00251348 [ 1.95952404] [ 0.119004]
# 74 0.00236522 [ 1.96073604] [ 0.11544122]
# 75 0.00222572 [ 1.96191132] [ 0.11198495]
# 76 0.00209444 [ 1.96305192] [ 0.10863232]
# 77 0.00197091 [ 1.96415794] [ 0.10537992]
# 78 0.00185466 [ 1.96523106] [ 0.10222496]
# 79 0.00174527 [ 1.966272] [ 0.09916444]
# 80 0.00164232 [ 1.96728182] [ 0.09619556]
# 81 0.00154546 [ 1.96826124] [ 0.09331552]
# 82 0.00145431 [ 1.96921158] [ 0.09052178]
# 83 0.00136853 [ 1.9701333] [ 0.08781163]
# 84 0.00128782 [ 1.97102761] [ 0.08518267]
# 85 0.00121185 [ 1.97189486] [ 0.08263232]
# 86 0.00114038 [ 1.97273636] [ 0.08015839]
# 87 0.00107312 [ 1.9735527] [ 0.07775855]
# 88 0.00100982 [ 1.97434425] [ 0.07543045]
# 89 0.000950259 [ 1.97511268] [ 0.07317225]
# 90 0.000894215 [ 1.97585762] [ 0.0709815]
# 91 0.000841465 [ 1.9765805] [ 0.06885641]
# 92 0.000791841 [ 1.97728157] [ 0.0667949]
# 93 0.000745135 [ 1.97796178] [ 0.06479514]
# 94 0.000701189 [ 1.9786216] [ 0.06285523]
# 95 0.000659824 [ 1.97926164] [ 0.06097339]
# 96 0.000620911 [ 1.9798826] [ 0.05914792]
# 97 0.000584291 [ 1.98048472] [ 0.05737704]
# 98 0.000549827 [ 1.98106921] [ 0.05565931]
# 99 0.0005174 [ 1.98163569] [ 0.05399282]
# 100 0.000486882 [ 1.98218572] [ 0.0523764]
#
# === Test ===
# X: 5, Y: [ 9.96330547]
# X: 2.5, Y: [ 5.00784063]
